# %% [markdown]
# Train a neural network using TensorFlow 2 to classify clothing images from the Fashion MNIST dataset into 10 categories.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from keras.datasets import fashion_mnist

# %%
#Load Dataset
(X_train,y_train),(X_test,y_test)=fashion_mnist.load_data()
X_train=X_train/255.0
X_test=X_test/255.0

# %%
#Build the model
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
# Out:
# c:\Users\ADARSH\.conda\envs\tf_env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Compile the model
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#Train the model
model.fit(X_train,y_train,epochs=10,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7841 - loss: 0.6300 - val_accuracy: 0.8542 - val_loss: 0.4078
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8618 - loss: 0.3879 - val_accuracy: 0.8610 - val_loss: 0.3733
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8725 - loss: 0.3449 - val_accuracy: 0.8808 - val_loss: 0.3477
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8852 - loss: 0.3171 - val_accuracy: 0.8800 - val_loss: 0.3291
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8894 - loss: 0.2975 - val_accuracy: 0.8813 - val_loss: 0.3421
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8958 - loss: 0.2838 - val_accuracy: 0.8670 - val_loss: 0.3724
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8997 - loss: 0.2701 - val_accuracy: 0.8862 - val_loss: 0.3165
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9061 - loss: 0.2528 - val_accuracy: 0.8798 - val_loss: 0.3418
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9046 - loss: 0.2534 - val_accuracy: 0.8803 - val_loss: 0.3459
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9113 - loss: 0.2364 - val_accuracy: 0.8795 - val_loss: 0.3381

# %%
#Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('\nTest accuracy:', test_acc)
# Out:
# Test accuracy: 0.8784999847412109

# %%
preds=model.predict(X_test[:5])
for i,pred in enumerate(preds):
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f"Predicted: {pred.argmax()}, True: {y_test[i]}")
    plt.axis('off')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
